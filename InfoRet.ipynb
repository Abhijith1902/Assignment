# %%
import os 
import pandas as pd
import string
import nltk
import nltk.corpus
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')

# %%
def Document(*doc_path):
  doc_files = []
  for files in doc_path:
    data_files = open(files)
    data_read = data_files.read()

    
    spcl_characters = '''!@#$%^&*-()[]{}.;:\'"/<>?''' 
    for element in data_read:
        if element in spcl_characters:
           data_read = data_read.replace(element, '') 
    
 
    text_tokens = [token for token in data_read.split()]

    clean_text = []
    for text in text_tokens:
      words = text.lower()
      if words not in stop_words:
        clean_text.append(words)
    
    doc_files.append(clean_text)
  return doc_files

# %%
docs=Document(r"C:\Users\Dell\Desktop\Stars.txt",r"C:\Users\Dell\Desktop\Galaxy.txt",r"C:\Users\Dell\Desktop\Black Holes.txt")

# %%
def word_pres(word):
  vector = []
  for word_token in docs:
    wrd = word.lower()
    if wrd in word_token:
      vector.append(1)
    else:
      vector.append(0)
  return vector

# %%
unique_words_list = []

for un_wrd in docs:
  unique_words_list += un_wrd
unique_list = []
for unq_wrd in unique_words_list:
  if unq_wrd not in unique_list:
    unique_list.append(unq_wrd)

# %%
unique_list
# Out:
# ['stars',
#  'widely',
#  'recognized',
#  'astronomical',
#  'objects,',
#  'represent',
#  'fundamental',
#  'building',
#  'blocks',
#  'galaxies',
#  'age,',
#  'distribution,',
#  'composition',
#  'galaxy',
#  'trace',
#  'history,',
#  'dynamics,',
#  'evolution',
#  'moreover,',
#  'responsible',
#  'manufacture',
#  'distribution',
#  'heavy',
#  'elements',
#  'carbon,',
#  'nitrogen,',
#  'oxygen,',
#  'characteristics',
#  'intimately',
#  'tied',
#  'planetary',
#  'systems',
#  'may',
#  'coalesce',
#  'consequently,',
#  'study',
#  'birth,',
#  'life,',
#  'death',
#  'central',
#  'field',
#  'astronomy',
#  'star',
#  'formation',
#  'born',
#  'within',
#  'clouds',
#  'dust',
#  'scattered',
#  'throughout',
#  'familiar',
#  'example',
#  'cloud',
#  'orion',
#  'nebula',
#  'turbulence',
#  'deep',
#  'gives',
#  'rise',
#  'knots',
#  'sufficient',
#  'mass',
#  'gas',
#  'begin',
#  'collapse',
#  'gravitational',
#  'attraction',
#  'collapses,',
#  'material',
#  'center',
#  'begins',
#  'heat',
#  'known',
#  'protostar,',
#  'hot',
#  'core',
#  'heart',
#  'collapsing',
#  'one',
#  'day',
#  'become',
#  'threedimensional',
#  'computer',
#  'models',
#  'predict',
#  'spinning',
#  'break',
#  'two',
#  'three',
#  'blobs',
#  'would',
#  'explain',
#  'majority',
#  'milky',
#  'way',
#  'paired',
#  'groups',
#  'multiple',
#  'dense,',
#  'forms',
#  'gathering',
#  'ends',
#  'part',
#  'â€”',
#  'remaining',
#  'planets,',
#  'asteroids,',
#  'comets',
#  'remain',
#  'cases,',
#  'steady',
#  'pace',
#  'january',
#  '2004,',
#  'amateur',
#  'astronomer,',
#  'james',
#  'mcneil,',
#  'discovered',
#  'small',
#  'appeared',
#  'unexpectedly',
#  'near',
#  'messier',
#  '78,',
#  'constellation',
#  'observers',
#  'around',
#  'world',
#  'pointed',
#  'instruments',
#  'mcneils',
#  'nebula,',
#  'found',
#  'something',
#  'interesting',
#  'brightness',
#  'appears',
#  'vary',
#  'observations',
#  'nasas',
#  'chandra',
#  'xray',
#  'observatory',
#  'provided',
#  'likely',
#  'explanation',
#  'interaction',
#  'young',
#  'magnetic',
#  'surrounding',
#  'causes',
#  'episodic',
#  'increases',
#  'main',
#  'sequence',
#  'size',
#  'sun',
#  'requires',
#  '50',
#  'million',
#  'years',
#  'mature',
#  'beginning',
#  'adulthood',
#  'stay',
#  'phase',
#  'shown',
#  'hertzsprungrussell',
#  'diagram',
#  'approximately',
#  '10',
#  'billion',
#  'fueled',
#  'nuclear',
#  'fusion',
#  'hydrogen',
#  'form',
#  'helium',
#  'interiors',
#  'outflow',
#  'energy',
#  'regions',
#  'provides',
#  'pressure',
#  'necessary',
#  'keep',
#  'weight,',
#  'shines',
#  'diagram,',
#  'span',
#  'wide',
#  'range',
#  'luminosities',
#  'colors,',
#  'classified',
#  'according',
#  'smallest',
#  'stars,',
#  'red',
#  'dwarfs,',
#  'contain',
#  'little',
#  'emit',
#  '001',
#  'much',
#  'energy,',
#  'glowing',
#  'feebly',
#  'temperatures',
#  '30004000k',
#  'despite',
#  'diminutive',
#  'nature,',
#  'dwarfs',
#  'far',
#  'numerous',
#  'universe',
#  'lifespans',
#  'tens',
#  'billions',
#  'hand,',
#  'massive',
#  'hypergiants,',
#  '100',
#  'times',
#  'sun,',
#  'surface',
#  '30,000',
#  'k',
#  'hypergiants',
#  'hundreds',
#  'thousands',
#  'lifetimes',
#  'although',
#  'extreme',
#  'believed',
#  'common',
#  'early',
#  'universe,',
#  'today',
#  'extremely',
#  'rare',
#  'entire',
#  'contains',
#  'handful',
#  'fates',
#  'general,',
#  'larger',
#  'star,',
#  'shorter',
#  'live',
#  'fused',
#  'core,',
#  'reactions',
#  'cease',
#  'deprived',
#  'production',
#  'needed',
#  'support',
#  'it,',
#  'becomes',
#  'hotter',
#  'still',
#  'available',
#  'outside',
#  'continues',
#  'shell',
#  'increasingly',
#  'also',
#  'pushes',
#  'outer',
#  'layers',
#  'outward,',
#  'causing',
#  'expand',
#  'cool,',
#  'transforming',
#  'giant',
#  'sufficiently',
#  'massive,',
#  'enough',
#  'exotic',
#  'consume',
#  'produce',
#  'variety',
#  'heavier',
#  'iron',
#  'however,',
#  'offer',
#  'temporary',
#  'reprieve',
#  'gradually,',
#  'internal',
#  'fires',
#  'unstable',
#  'sometimes',
#  'burning',
#  'furiously,',
#  'dying',
#  'variations',
#  'cause',
#  'pulsate',
#  'throw',
#  'layers,',
#  'enshrouding',
#  'cocoon',
#  'happens',
#  'next',
#  'depends',
#  'galaxy,',
#  'way,',
#  'typical',
#  'make',
#  'least',
#  'ten',
#  'dark',
#  'matter',
#  'put',
#  'together',
#  'itâ€™s',
#  'held',
#  'gravity',
#  'like',
#  'twothirds',
#  'galaxies,',
#  'spiral',
#  'shape',
#  'spiral,',
#  'lot',
#  'and,',
#  'occasionally,',
#  'vivid',
#  'flares',
#  'generated',
#  'based',
#  'immense',
#  'required',
#  'movement',
#  'expelled,',
#  'astronomers',
#  'conclude',
#  'supermassive',
#  'black',
#  'hole',
#  'elliptical',
#  'shapes,',
#  'unusual',
#  'shapes',
#  'toothpicks',
#  'rings',
#  'hubble',
#  'ultra',
#  'hudf',
#  'shows',
#  'diversity',
#  'observed',
#  'tiny',
#  'patch',
#  'sky',
#  'onetenth',
#  'diameter',
#  'moon',
#  'seconds',
#  '116',
#  'days',
#  '10,000',
#  'sizes,',
#  'colors',
#  'ground,',
#  'see',
#  'spot,',
#  'fornax',
#  'big',
#  'bang,',
#  'composed',
#  'radiation',
#  'subatomic',
#  'particles',
#  'happened',
#  'debate',
#  'slowly',
#  'team',
#  'gradually',
#  'clusters,',
#  'eventually',
#  'first',
#  'organize',
#  'clumps',
#  'later',
#  'subdivided',
#  'collisions',
#  'influenced',
#  'neighbors,',
#  'often,',
#  'collide',
#  'collision',
#  'course',
#  'nearest',
#  'neighbor,',
#  'andromeda',
#  'even',
#  'though',
#  'age',
#  'reveal',
#  'andromedas',
#  'halo',
#  'younger',
#  'evidence,',
#  'infer',
#  'already',
#  'smashed',
#  'maybe',
#  'several',
#  'holes',
#  'dont',
#  'let',
#  'name',
#  'fool',
#  'anything',
#  'empty',
#  'space',
#  'rather,',
#  'great',
#  'amount',
#  'packed',
#  'area',
#  'think',
#  'squeezed',
#  'sphere',
#  'new',
#  'york',
#  'city',
#  'result',
#  'strong',
#  'nothing,',
#  'light,',
#  'escape',
#  'recent',
#  'years,',
#  'nasa',
#  'painted',
#  'picture',
#  'strange',
#  'objects',
#  'are,',
#  'many,',
#  'fascinating',
#  'spacethe',
#  'idea',
#  'object',
#  'dense',
#  'light',
#  'could',
#  'centuries',
#  'famously,',
#  'predicted',
#  'einsteins',
#  'theory',
#  'general',
#  'relativity,',
#  'showed',
#  'dies,',
#  'leaves',
#  'behind',
#  'small,',
#  'remnant',
#  'cores',
#  'equations',
#  'showed,',
#  'force',
#  'overwhelms',
#  'forces',
#  'produces',
#  'holescientists',
#  'cant',
#  'directly',
#  'observe',
#  'telescopes',
#  'detect',
#  'xrays,',
#  'electromagnetic',
#  'can,',
#  'presence',
#  'detecting',
#  'effect',
#  'nearby',
#  'passes',
#  'interstellar',
#  'matter,',
#  'example,',
#  'draw',
#  'inward',
#  'process',
#  'accretion',
#  'similar',
#  'occur',
#  'normal',
#  'close',
#  'case,',
#  'tear',
#  'apart',
#  'pulls',
#  'toward',
#  'attracted',
#  'accelerates',
#  'heats',
#  'up,',
#  'emits',
#  'xrays',
#  'radiate',
#  'discoveries',
#  'tantalizing',
#  'evidence',
#  'dramatic',
#  'influence',
#  'neighborhoods',
#  'emitting',
#  'powerful',
#  'gamma',
#  'ray',
#  'bursts,',
#  'devouring',
#  'spurring',
#  'growth',
#  'areas',
#  'stalling',
#  'others',
#  'end',
#  'remnants',
#  'large',
#  'dies',
#  'supernova',
#  'explosion',
#  'smaller',
#  'neutron',
#  'trap',
#  'total',
#  'proven',
#  'theoretically',
#  'thing',
#  'occurs',
#  'nears',
#  'imaginary',
#  'called',
#  'event',
#  'horizon,',
#  'time',
#  'slows',
#  'relative',
#  'kept',
#  'away',
#  'reaches',
#  'stands',
#  'still,',
#  'frozen',
#  'bigger',
#  'stellar',
#  'soon',
#  'launch',
#  'december',
#  'swift',
#  'telescope',
#  'powerful,',
#  'fleeting',
#  'flashes',
#  'bursts',
#  'collected',
#  'data',
#  'events',
#  'afterglow,',
#  'led',
#  'explosions',
#  'collide,',
#  'producing',
#  'another',
#  'babies',
#  'giants',
#  'basic',
#  'understood,',
#  'perennial',
#  'mystery',
#  'science',
#  'appear',
#  'exist',
#  'radically',
#  'different',
#  'scales',
#  'end,',
#  'countless',
#  'peppered',
#  'generally',
#  '24',
#  'spot',
#  'draws',
#  'snared',
#  'gravity,',
#  'churning',
#  'holes,',
#  'difficult',
#  'judging',
#  'number',
#  'scientists',
#  'estimate',
#  'many',
#  'alone',
#  'spectrum',
#  'millions,',
#  'billions,',
#  'believe',
#  'lie',
#  'virtually',
#  'watching',
#  'effects',
#  'historically,',
#  'long',
#  'midsized',
#  'chandra,',
#  'xmmnewton',
#  'strengthens',
#  'case',
#  'midsize',
#  'possible',
#  'mechanism',
#  'involves',
#  'chain',
#  'reaction',
#  'compact',
#  'clusters',
#  'results',
#  'buildup',
#  'intermediatemass',
#  'sink',
#  'merge']

# %%
unique_dict = {}
for w in unique_list:
  unique_dict[w] = word_pres(w)

# %%
column_names = ['']

# %%
def process_query(query_text):
  query = word_tokenize(query_text)
  words_connect= []
  words_different = []

  for word in query:
      if word.lower() != "and" and word.lower() != "or" and word.lower() != "not":
        words_different.append(word.lower())
      else:
        words_connect.append(word.lower())

  for word in words_connect:
     words_list1 = unique_dict[words_different[0]]
     words_list2 = unique_dict[words_different[1]]
     if word == "and":
        bitwise_op = [w1 & w2 for (w1,w2) in zip(words_list1, words_list2)]
     elif word == "or":
        bitwise_op = [w1 | w2 for (w1,w2) in zip(words_list1, words_list2)]
     elif word == "not":
        bitwise_op = [not w1 for w1 in words_list2]
        bitwise_op = [int(b == True) for b in bitwise_op]
        bitwise_op = [w1 & w2 for (w1, w2) in zip(words_list1, bitwise_op)]
  return bitwise_op

# %%
q1 = input("Enter the query: ")
process_query(q1)
# Out:
# Enter the query: stars or nebula and black hole
# [1, 0, 0]

# %%
q2 = input("Enter the query: ")
process_query(q2)
# Out:
# Enter the query: neutron star and not black hole
# [0, 0, 0]
